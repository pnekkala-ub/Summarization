# %% [markdown]
# Install dependecies

# %%
# !pip install transformers[torch] datasets==2.10.0 evaluate rouge_score -q
# !pip install git+https://github.com/google-research/bleurt.git -q
# !pip install bert_score -q
# !pip install demoji -q
# Out:
#   Preparing metadata (setup.py) ... done

# %% [markdown]
# Imports

# %%
from datasets import load_dataset
import json
from transformers import DataCollatorForSeq2Seq, AutoTokenizer, AutoModelForSeq2SeqLM, Seq2SeqTrainingArguments, Seq2SeqTrainer
import evaluate
import numpy as np
import torch
import demoji

# %% [markdown]
# Load and preprocess data. Remove emojis, file embeddings and \r, \n.

# %%
path = "drive/MyDrive/NLP/PR/"
dataset = load_dataset("json", data_files={"train":[path+"samsum/train.json"], "val":[path+"samsum/val.json"], "test":[path+"samsum/test.json"]})
# Out:
# WARNING:datasets.builder:Found cached dataset json (/root/.cache/huggingface/datasets/json/default-90b80b69531c1da8/0.0.0/0f7e3662623656454fcd2b650f34e886a7db4b9104504885bd462096cc7a9f51)
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
def preprocess(examples):
  processed = []
  out = {}
  # print(examples)
  for k, v in examples.items():
    if k!="id":
      for x in v:
        processed.append(demoji.replace(x.replace("\r","").replace("\n"," "), ''))
      out[k] = processed
      processed=[]
  return out



# def give_emoji_free_text(text):
#     return demoji.replace(text, '')

dataset = dataset.map(preprocess, batched=True)
# Out:
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /root/.cache/huggingface/datasets/json/default-90b80b69531c1da8/0.0.0/0f7e3662623656454fcd2b650f34e886a7db4b9104504885bd462096cc7a9f51/cache-d19e856d7cfb3406.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /root/.cache/huggingface/datasets/json/default-90b80b69531c1da8/0.0.0/0f7e3662623656454fcd2b650f34e886a7db4b9104504885bd462096cc7a9f51/cache-7f91c923976b16b6.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /root/.cache/huggingface/datasets/json/default-90b80b69531c1da8/0.0.0/0f7e3662623656454fcd2b650f34e886a7db4b9104504885bd462096cc7a9f51/cache-e579a2a8c16c1dd7.arrow

# %% [markdown]
# Load model and tokenizer

# %%
checkpoint = "google/flan-t5-base"
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
model = AutoModelForSeq2SeqLM.from_pretrained(checkpoint)

# %% [markdown]
# tokenize and create batches of data

# %%
def batchify(examples):
  dialogues = ["summarize: "+x for x in examples["dialogue"]]
  data = tokenizer(dialogues, max_length=256, truncation=True, padding="max_length")
  labels = tokenizer(text_target=examples["summary"], max_length=64, truncation=True, padding="max_length")
  data["labels"] = labels["input_ids"]
  return data

# %%
dataset = dataset.map(batchify, batched=True, remove_columns=["id","dialogue","summary"])
data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, model=model)
# Out:
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /root/.cache/huggingface/datasets/json/default-90b80b69531c1da8/0.0.0/0f7e3662623656454fcd2b650f34e886a7db4b9104504885bd462096cc7a9f51/cache-eb4e5b2b2808d53b.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /root/.cache/huggingface/datasets/json/default-90b80b69531c1da8/0.0.0/0f7e3662623656454fcd2b650f34e886a7db4b9104504885bd462096cc7a9f51/cache-4b915097f1010043.arrow
# Map:   0%|          | 0/819 [00:00<?, ? examples/s]

# %% [markdown]
# Define evaluation metrics

# %%
rouge = evaluate.load("rouge")
bleu = evaluate.load('bleu')
bleurt = evaluate.load('bleurt', module_type='metric', checkpoint='bleurt-base-512')
bert = evaluate.load('bertscore', lang="en", idf=True)
# Out:
# WARNING:evaluate_modules.metrics.evaluate-metric--bleurt.98e148b2f8c4a88aba5037e4e0e90c9fd9ec35dc37a054ded8cfef0fa801ffab.bleurt:Using default BLEURT-Base checkpoint for sequence maximum length 128. You can use a bigger model for better results with e.g.: evaluate.load('bleurt', 'bleurt-large-512').
# Computing checksums: 100%|##########| 1/1 [00:06<00:00,  6.67s/it]

# %% [markdown]
# Utility function to compute the desired metrics

# %%
# def preprocess_logits_for_metrics(preds, labels):
#     preds = preds.argmax(-1).squeeze()
#     return preds

def compute_metrics(preds):
    predictions, labels = preds
    decoded_preds = tokenizer.batch_decode(predictions, skip_special_tokens=True)
    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)

    print(decoded_preds, decoded_labels)

    rouge_score = rouge.compute(predictions=decoded_preds, references=decoded_labels, use_stemmer=True)
    bleu_score = bleu.compute(predictions=decoded_preds, references=decoded_labels)
    prediction_lens = [np.count_nonzero(pred != tokenizer.pad_token_id) for pred in predictions]
    bleurt_score = bleurt.compute(predictions=decoded_preds, references=decoded_labels)
    bert_score = bert.compute(predictions=decoded_preds, references=decoded_labels, lang="en")
    result = {
        "gen_len": np.mean(prediction_lens),
        "rouge_score": rouge_score,
        "bleu_score": bleu_score,
        "bleurt_score":np.median(bleurt_score["scores"]),
        "bert_score":[np.mean(np.array(bert_score[k], dtype=np.float32)) for k in ["precision","recall","f1"]]
    }

    return result

# %% [markdown]
# Training loop

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
training_args = Seq2SeqTrainingArguments(
    output_dir="flant5_sum_samsum",
    overwrite_output_dir=True,
    evaluation_strategy="epoch",
    # eval_steps=1,
    learning_rate=2e-4,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    weight_decay=0.01,
    save_strategy="no",
    logging_strategy="epoch",
    num_train_epochs=10,
    predict_with_generate=True,
    fp16=True,
    push_to_hub=True,
    disable_tqdm=False,
    hub_strategy="end",
    push_to_hub_token="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"
)

model = model.to(device)

trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    train_dataset=dataset["train"],
    eval_dataset=dataset["val"],
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
    # preprocess_logits_for_metrics=preprocess_logits_for_metrics
)

trainer.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1617: FutureWarning: `--push_to_hub_token` is deprecated and will be removed in version 5 of 🤗 Transformers. Use `--hub_token` instead.
#   warnings.warn(
# /content/flant5_sum_samsum is already a clone of https://huggingface.co/sentientconch/flant5_sum_samsum. Make sure you pull the latest changes with `repo.git_pull()`.
# WARNING:huggingface_hub.repository:/content/flant5_sum_samsum is already a clone of https://huggingface.co/sentientconch/flant5_sum_samsum. Make sure you pull the latest changes with `repo.git_pull()`.
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='9210' max='9210' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [9210/9210 1:30:38, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Gen Len</th>
#       <th>Rouge Score</th>
#       <th>Bleu Score</th>
#       <th>Bleurt Score</th>
#       <th>Bert Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.000000</td>
#       <td>nan</td>
#       <td>16.676039</td>
#       <td>{'rouge1': 0.4648609117501229, 'rouge2': 0.23489748856950105, 'rougeL': 0.3936027885754436, 'rougeLsum': 0.3932448622689456}</td>
#       <td>{'bleu': 0.12048170853922512, 'precisions': [0.5838656689176857, 0.28994082840236685, 0.17667882428663376, 0.11335841956726246], 'brevity_penalty': 0.49929356415876747, 'length_ratio': 0.5901233238192687, 'translation_length': 10958, 'reference_length': 18569}</td>
#       <td>-0.486309</td>
#       <td>[0.9187235832214355, 0.9003126621246338, 0.9092234373092651]</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.000000</td>
#       <td>nan</td>
#       <td>16.676039</td>
#       <td>{'rouge1': 0.4648609117501229, 'rouge2': 0.23489748856950105, 'rougeL': 0.3936027885754436, 'rougeLsum': 0.3932448622689456}</td>
#       <td>{'bleu': 0.12048170853922512, 'precisions': [0.5838656689176857, 0.28994082840236685, 0.17667882428663376, 0.11335841956726246], 'brevity_penalty': 0.49929356415876747, 'length_ratio': 0.5901233238192687, 'translation_length': 10958, 'reference_length': 18569}</td>
#       <td>-0.486309</td>
#       <td>[0.9187235832214355, 0.9003126621246338, 0.9092234373092651]</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.000000</td>
#       <td>nan</td>
#       <td>16.676039</td>
#       <td>{'rouge1': 0.4648609117501229, 'rouge2': 0.23489748856950105, 'rougeL': 0.3936027885754436, 'rougeLsum': 0.3932448622689456}</td>
#       <td>{'bleu': 0.12048170853922512, 'precisions': [0.5838656689176857, 0.28994082840236685, 0.17667882428663376, 0.11335841956726246], 'brevity_penalty': 0.49929356415876747, 'length_ratio': 0.5901233238192687, 'translation_length': 10958, 'reference_length': 18569}</td>
#       <td>-0.486309</td>
#       <td>[0.9187235832214355, 0.9003126621246338, 0.9092234373092651]</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.000000</td>
#       <td>nan</td>
#       <td>16.676039</td>
#       <td>{'rouge1': 0.4648609117501229, 'rouge2': 0.23489748856950105, 'rougeL': 0.3936027885754436, 'rougeLsum': 0.3932448622689456}</td>
#       <td>{'bleu': 0.12048170853922512, 'precisions': [0.5838656689176857, 0.28994082840236685, 0.17667882428663376, 0.11335841956726246], 'brevity_penalty': 0.49929356415876747, 'length_ratio': 0.5901233238192687, 'translation_length': 10958, 'reference_length': 18569}</td>
#       <td>-0.486309</td>
#       <td>[0.9187235832214355, 0.9003126621246338, 0.9092234373092651]</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.000000</td>
#       <td>nan</td>
#       <td>16.676039</td>
#       <td>{'rouge1': 0.4648609117501229, 'rouge2': 0.23489748856950105, 'rougeL': 0.3936027885754436, 'rougeLsum': 0.3932448622689456}</td>
#       <td>{'bleu': 0.12048170853922512, 'precisions': [0.5838656689176857, 0.28994082840236685, 0.17667882428663376, 0.11335841956726246], 'brevity_penalty': 0.49929356415876747, 'length_ratio': 0.5901233238192687, 'translation_length': 10958, 'reference_length': 18569}</td>
#       <td>-0.486309</td>
#       <td>[0.9187235832214355, 0.9003126621246338, 0.9092234373092651]</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.000000</td>
#       <td>nan</td>
#       <td>16.676039</td>
#       <td>{'rouge1': 0.4648609117501229, 'rouge2': 0.23489748856950105, 'rougeL': 0.3936027885754436, 'rougeLsum': 0.3932448622689456}</td>
#       <td>{'bleu': 0.12048170853922512, 'precisions': [0.5838656689176857, 0.28994082840236685, 0.17667882428663376, 0.11335841956726246], 'brevity_penalty': 0.49929356415876747, 'length_ratio': 0.5901233238192687, 'translation_length': 10958, 'reference_length': 18569}</td>
#       <td>-0.486309</td>
#       <td>[0.9187235832214355, 0.9003126621246338, 0.9092234373092651]</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.000000</td>
#       <td>nan</td>
#       <td>16.676039</td>
#       <td>{'rouge1': 0.4648609117501229, 'rouge2': 0.23489748856950105, 'rougeL': 0.3936027885754436, 'rougeLsum': 0.3932448622689456}</td>
#       <td>{'bleu': 0.12048170853922512, 'precisions': [0.5838656689176857, 0.28994082840236685, 0.17667882428663376, 0.11335841956726246], 'brevity_penalty': 0.49929356415876747, 'length_ratio': 0.5901233238192687, 'translation_length': 10958, 'reference_length': 18569}</td>
#       <td>-0.486309</td>
#       <td>[0.9187235832214355, 0.9003126621246338, 0.9092234373092651]</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.000000</td>
#       <td>nan</td>
#       <td>16.676039</td>
#       <td>{'rouge1': 0.4648609117501229, 'rouge2': 0.23489748856950105, 'rougeL': 0.3936027885754436, 'rougeLsum': 0.3932448622689456}</td>
#       <td>{'bleu': 0.12048170853922512, 'precisions': [0.5838656689176857, 0.28994082840236685, 0.17667882428663376, 0.11335841956726246], 'brevity_penalty': 0.49929356415876747, 'length_ratio': 0.5901233238192687, 'translation_length': 10958, 'reference_length': 18569}</td>
#       <td>-0.486309</td>
#       <td>[0.9187235832214355, 0.9003126621246338, 0.9092234373092651]</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.000000</td>
#       <td>nan</td>
#       <td>16.676039</td>
#       <td>{'rouge1': 0.4648609117501229, 'rouge2': 0.23489748856950105, 'rougeL': 0.3936027885754436, 'rougeLsum': 0.3932448622689456}</td>
#       <td>{'bleu': 0.12048170853922512, 'precisions': [0.5838656689176857, 0.28994082840236685, 0.17667882428663376, 0.11335841956726246], 'brevity_penalty': 0.49929356415876747, 'length_ratio': 0.5901233238192687, 'translation_length': 10958, 'reference_length': 18569}</td>
#       <td>-0.486309</td>
#       <td>[0.9187235832214355, 0.9003126621246338, 0.9092234373092651]</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.000000</td>
#       <td>nan</td>
#       <td>16.676039</td>
#       <td>{'rouge1': 0.4648609117501229, 'rouge2': 0.23489748856950105, 'rougeL': 0.3936027885754436, 'rougeLsum': 0.3932448622689456}</td>
#       <td>{'bleu': 0.12048170853922512, 'precisions': [0.5838656689176857, 0.28994082840236685, 0.17667882428663376, 0.11335841956726246], 'brevity_penalty': 0.49929356415876747, 'length_ratio': 0.5901233238192687, 'translation_length': 10958, 'reference_length': 18569}</td>
#       <td>-0.486309</td>
#       <td>[0.9187235832214355, 0.9003126621246338, 0.9092234373092651]</td>
#     </tr>
#   </tbody>
# </table><p>
# ['B: Hi Tom, are you busy tomorrow afternoon?', 'Emma wants to buy an advent calendar for her kids. Rob used to get one every year as', 'Madison is pregnant. Iggy and Jackie are worried about it. Iggy used to think that', 'Marla finds a pink underwear under her bed.', 'Robert needs to buy guitar cable. Fred will find it on google maps.', 'Keith wants to buy milk and cereals. Megan will check the drawer next to the fridge', 'Samantha and Evelyn are surprised that Samatha is making that noise.', "Tom's new place is in Fiesole. He invited Luis and Adam for dinner", 'Jane wants to make a reservation for 6 people tonight at 21:00. Vegano Resto', "Nancy's Texan drawl. Kids behaving themselves. Nancy is coming home", 'Laura needs a new printer. Jamie recommends Laura to buy a second hand one.', "Haylee is in the dairy section. She's looking for the coconut milk youg", 'Norbert and Wendy need to hurry to catch the tour. Norbert missed the last one because', 'Cheryl went to the Jandia Peninsula. Peter took nice pictures. Tomorrow they will', "Sophie hasn't found it yet.", "Dennis's favorite b-movie is Toxic Avenger. Elle", 'James wants to become a voice actor. He has a dream for a long time', 'Poppy and Alice have a long day. Alice has errands. Po', "Sash needs to see Caron. Caron is out from 12 and she's out", 'Gosia criticizes Matteo because he likes football and video games', "Jannette is coming to Ramzi's.", 'Jeniffer and Hildegard are preparing ravioli.', 'Lawrence is not finished with the article yet. He will be in a few minutes.', "Chad and Brennen are laughing at Brennen's joke.", 'Sadie needs to go to the dentist on Thursday. Chloe will pick it up', 'Carter is developing a restaurant business. He is a bit nervous about it. He is', "Kenny is back from surgery. He has another surgery tomorrow. He's got another", 'Joey and Olivia broke up after years of dating. Joey cheated on Olivia with', 'Amanda is pregnant. She went dancing classes with Michael yesterday. The instructor needed a partner to', "Taylor hasn't introduced Isabel to her boyfriend yet. Isabel hasn't introduced Taylor", 'Theo is leaving on Friday and will join him for the weekend. He will come back by', 'Brandon is late. Clara will prepare a report on absenteeism and late', "Suzie is sick again and she cancels Olga's meeting. Olga", "Kate will be Diane's kids' mother.", 'Andrew has a cold. He has to call in sick. Daniel will pick up some stuff', 'John, Alex and Sam are watching Millionaires on TV.', 'Angelica has the cinnamon cookies recipe.', 'Sophie is waiting for a client who is 40 minutes late. Sophie will let Gwen', 'Daniel is on his way. Sue is going downstairs now.', 'George will pan fry the salmon and stuff the squash with salmon. Betty will pick up some', "Ken tried to track his progress with endomondo. Martha noticed that Ken's phone", "Ivan hasn't been at Ann's party. Ann and Ivan are meeting", 'Ashley posted nudes on Facebook. Rowan thinks it\'s "art" and Row', "Mikolaj got a letter from the government saying that his wife's papers will", 'Ann is at the hotel. Thomas and Maria are going to have lunch together.', 'Sus and Val are sleepy.', "Kate and Kai are at the Guggenheim. They're going to the Museum of", "Cathy left her sunglasses at Broke's house. She will come round at 10 tonight", 'Bradley invites Frederica to his birthday party tomorrow at 8 pm.', 'Camilla received 250 dollars.', "Lilliana is waiting to have lunch and maybe nap. She's not getting paid for", 'Margaret has just had a shower. She will go shopping with Meg at 1 pm near', 'Maria Curie is the greatest Pole. Paulina thinks she is not appreciated enough in', 'Miles needs to push the project. Tim knows, Tim is doing his best. Gregory has', 'Julia is at work. Morgan wants to meet up for a drink later.', "Marta is at the supermarket to make some shopping for today's dinner. Nick hasn", 'Dzuka wants to change the time of the staff meeting. Anna will let Dzuka', "Will is checking Daniel's tests ...
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Trainer is attempting to log a value of "{'rouge1': 0.4648609117501229, 'rouge2': 0.23489748856950105, 'rougeL': 0.3936027885754436, 'rougeLsum': 0.3932448622689456}" of type <class 'dict'> for key "eval/rouge_score" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'bleu': 0.12048170853922512, 'precisions': [0.5838656689176857, 0.28994082840236685, 0.17667882428663376, 0.11335841956726246], 'brevity_penalty': 0.49929356415876747, 'length_ratio': 0.5901233238192687, 'translation_length': 10958, 'reference_length': 18569}" of type <class 'dict'> for key "eval/bleu_score" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[0.9187235832214355, 0.9003126621246338, 0.9092234373092651]" of type <class 'list'> for key "eval/bert_score" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# ['B: Hi Tom, are you busy tomorrow afternoon?', 'Emma wants to buy an advent calendar for her kids. Rob used to get one every year as', 'Madison is pregnant. Iggy and Jackie are worried about it. Iggy used to think that', 'Marla finds a pink underwear under her bed.', 'Robert needs to buy guitar cable. Fred will find it on google maps.', 'Keith wants to buy milk and cereals. Megan will check the drawer next to the fridge', 'Samantha and Evelyn are surprised that Samatha is making that noise.', "Tom's new place is in Fiesole. He invited Luis and Adam for dinner", 'Jane wants to make a reservation for 6 people tonight at 21:00. Vegano Resto', "Nancy's Texan drawl. Kids behaving themselves. Nancy is coming home", 'Laura needs a new printer. Jamie recommends Laura to buy a second hand one.', "Haylee is in the dairy section. She's looking for the coconut milk youg", 'Norbert and Wendy need to hurry to catch the tour. Norbert missed the last one because', 'Cheryl went to the Jandia Peninsula. Peter took nice pictures. Tomorrow they will', "Sophie hasn't found it yet.", "Dennis's favorite b-movie is Toxic Avenger. Elle", 'James wants to become a voice actor. He has a dream for a long time', 'Poppy
score" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[0.9187235832214355, 0.9003126621246338, 0.9092234373092651]" of type <class 'list'> for key "eval/bert_score" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# ['B: Hi Tom, are you busy tomorrow afternoon?', 'Emma wants to buy an advent calendar for her kids. Rob used to get one every year as', 'Madison is pregnant. Iggy and Jackie are worried about it. Iggy used to think that', 'Marla finds a pink underwear under her bed.', 'Robert needs to buy guitar cable. Fred will find it on google maps.', 'Keith wants to buy milk and cereals. Megan will check the drawer next to the fridge', 'Samantha and Evelyn are surprised that Samatha is making that noise.', "Tom's new place is in Fiesole. He invited Luis and Adam for dinner", 'Jane wants to make a reservation for 6 people tonight at 21:00. Vegano Resto', "Nancy's Texan drawl. Kids behaving themselves. Nancy is coming home", 'Laura needs a new printer. Jamie recommends Laura to buy a second hand one.', "Haylee is in the dairy section. She's looking for the coconut milk youg", 'Norbert and Wendy need to hurry to catch the tour. Norbert missed the last one because', 'Cheryl went to the Jandia Peninsula. Peter took nice pictures. Tomorrow they will', "Sophie hasn't found it yet.", "Dennis's favorite b-movie is Toxic Avenger. Elle", 'James wants to become a voice actor. He has a dream for a long time', 'Poppy and Alice have a long day. Alice has errands. Po', "Sash needs to see Caron. Caron is out from 12 and she's out", 'Gosia criticizes Matteo because he likes football and video games', "Jannette is coming to Ramzi's.", 'Jeniffer and Hildegard are preparing ravioli.', 'Lawrence is not finished with the article yet. He will be in a few minutes.', "Chad and Brennen are laughing at Brennen's joke.", 'Sadie needs to go to the dentist on Thursday. Chloe will pick it up', 'Carter is developing a restaurant business. He is a bit nervous about it. He is', "Kenny is back from surgery. He has another surgery tomorrow. He's got another", 'Joey and Olivia broke up after years of dating. Joey cheated on Olivia with', 'Amanda is pregnant. She went dancing classes with Michael yesterday. The instructor needed a partner to', "Taylor hasn't introduced Isabel to her boyfriend yet. Isabel hasn't introduced Taylor", 'Theo is leaving on Friday and will join him for the weekend. He will come back by', 'Brandon is late. Clara will prepare a report on absenteeism and late', "Suzie is sick again and she cancels Olga's meeting. Olga", "Kate will be Diane's kids' mother.", 'Andrew has a cold. He has to call in sick. Daniel will pick up some stuff', 'John, Alex and Sam are watching Millionaires on TV.', 'Angelica has the cinnamon cookies recipe.', 'Sophie is waiting for a client who is 40 minutes late. Sophie will let Gwen', 'Daniel is on his way. Sue is going downstairs now.', 'George will pan fry the salmon and stuff the squash with salmon. Betty will pick up some', "Ken tried to track his progress with endomondo. Martha noticed that Ken's phone", "Ivan hasn't been at Ann's party. Ann and Ivan are meeting", 'Ashley posted nudes on Facebook. Rowan thinks it\'s "art" and Row', "Mikolaj got a letter from the government saying that his wife's papers will", 'Ann is at the hotel. Thomas and Maria are going to have lunch together.', 'Sus and Val are sleepy.', "Kate and Kai are at the Guggenheim. They're going to the Museum of", "Cathy left her sunglasses at Broke's house. She will come round at 10 tonight", 'Bradley invites Frederica to his birthday party tomorrow at 8 pm.', 'Camilla received 250 dollars.', "Lilliana is waiting to have lunch and maybe nap. She's not getting paid for", 'Margaret has just had a shower. She will go shopping with Meg at 1 pm near', 'Maria Curie is the greatest Pole. Paulina thinks she is not appreciated enough in', 'Miles needs to push the project. Tim knows, Tim is doing his best. Gregory has', 'Julia is at work. Morgan wants to meet up for a drink later.', "Marta is at the supermarket to make some shopping for today's dinner. Nick hasn", 'Dzuka wants to change the time of the staff meeting. Anna will let Dzuka', "Will is checking Daniel's tests ...
# Trainer is attempting to log a value of "{'rouge1': 0.4648609117501229, 'rouge2': 0.23489748856950105, 'rougeL': 0.3936027885754436, 'rougeLsum': 0.3932448622689456}" of type <class 'dict'> for key "eval/rouge_score" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'bleu': 0.12048170853922512, 'precisions': [0.5838656689176857, 0.28994082840236685, 0.17667882428663376, 0.11335841956726246], 'brevity_penalty': 0.49929356415876747, 'length_ratio': 0.5901233238192687, 'translation_length': 10958, 'reference_length': 18569}" of type <class 'dict'> for key "eval/bleu_score" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[0.9187235832214355, 0.9003126621246338, 0.9092234373092651]" of type <class 'list'> for key "eval/bert_score" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# ['B: Hi Tom, are you busy tomorrow afternoon?', 'Emma wants to buy an advent calendar for her kids. Rob used to get one every year as', 'Madison is pregnant. Iggy and Jackie are worried about it. Iggy used to think that', 'Marla finds a pink underwear under her bed.', 'Robert needs to buy guitar cable. Fred will find it on google maps.', 'Keith wants to buy milk and cereals. Megan will check the drawer next to the fridge', 'Samantha and Evelyn are surprised that Samatha is making that noise.', "Tom's new place is in Fiesole. He invited Luis and Adam for dinner", 'Jane wants to make a reservation for 6 people tonight at 21:00. Vegano Resto', "Nancy's Texan drawl. Kids behaving themselves. Nancy is coming home", 'Laura needs a new printer. Jamie recommends Laura to buy a second hand one.', "Haylee is in the dairy section. She's looking for the coconut milk youg", 'Norbert and Wendy need to hurry to catch the tour. Norbert missed the last one because', 'Cheryl went to the Jandia Peninsula. Peter took nice pictures. Tomorrow they will', "Sophie hasn't found it yet.", "Dennis's favorite b-movie is Toxic Avenger. Elle", 'James wants to become a voice actor. He has a dream for a long time', 'Poppy and Alice have a long day. Alice has errands. Po', "Sash needs to see Caron. Caron is out from 12 and she's out", 'Gosia criticizes Matteo because he likes football and video games', "Jannette is coming to Ramzi's.", 'Jeniffer and Hildegard are preparing ravioli.', 'Lawrence is not finished with the article yet. He will be in a few minutes.', "Chad and Brennen are laughing at Brennen's joke.", 'Sadie needs to go to the dentist on Thursday. Chloe will pick it up', 'Carter is developing a restaurant business. He is a bit nervous about it. He is', "Kenny is back from surgery. He has another surgery tomorrow. He's got another", 'Joey and Olivia broke up after years of dating. Joey cheated on Olivia with', 'Amanda is pregnant. She went dancing classes with Michael yesterday. The instructor needed a partner to', "Taylor hasn't introduced Isabel to her boyfriend yet. Isabel hasn't introduced Taylor", 'Theo is leaving on Friday and will join him for the weekend. He will come back by', 'Brandon is late. Clara will prepare a report on absenteeism and late', "Suzie is sick again and she cancels Olga's meeting. Olga", "Kate will be Diane's kids' mother.", 'Andrew has a cold. He has to call in sick. Daniel will pick up some stuff', 'John, Alex and Sam are watching Millionaires on TV.', 'Angelica has the cinnamon cookies recipe.', 'Sophie is waiting for a client who is 40 minutes late. Sophie will let Gwen', 'Daniel is on his way. Sue is going downstairs now.', 'George will pan fry the salmon and stuff the squash with salmon. Betty will pick up some', "Ken tried to track his progress with endomondo. Martha noticed that Ken's phone", "Ivan hasn't been at Ann's party. Ann and Ivan are meeting", 'Ashley posted nudes on Facebook. Rowan thinks it\'s "art" and Row', "Mikolaj got a letter from the government saying that his wife's papers will", 'Ann is at the hotel. Thomas and Maria are going to have lunch together.', 'Sus and Val are sleepy.', "Kate and Kai are at the Guggenheim. They're going to the Museum of", "Cathy left her sunglasses at Broke's house. She will come round at 10 tonight", 'Bradley invites Frederica to his birthday party tomorrow at 8 pm.', 'Camilla received 250 dollars.', "Lilliana is waiting to have lunch and maybe nap. She's not getting paid for", 'Margaret has just had a shower. She will go shopping with Meg at 1 pm near', 'Maria Curie is the greatest Pole. Paulina thinks she is not appreciated enough in', 'Miles needs to push the project. Tim knows, Tim is doing his best. Gregory has', 'Julia is at work. Morgan wants to meet up for a drink later.', "Marta is at the supermarket to make some shopping for today's dinner. Nick hasn", 'Dzuka wants to change the time of the staff meeting. Anna will let Dzuka', "Will is checking Daniel's tests ...
# Trainer is attempting to log a value of "{'rouge1': 0.4648609117501229, 'rouge2': 0.23489748856950105, 'rougeL': 0.3936027885754436, 'rougeLsum': 0.3932448622689456}" of type <class 'dict'> for key "eval/rouge_score" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'bleu': 0.12048170853922512, 'precisions': [0.5838656689176857, 0.28994082840236685, 0.17667882428663376, 0.11335841956726246], 'brevity_penalty': 0.49929356415876747, 'length_ratio': 0.5901233238192687, 'translation_length': 10958, 'reference_length': 18569}" of type <class 'dict'> for key "eval/bleu_score" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[0.9187235832214355, 0.9003126621246338, 0.9092234373092651]" of type <class 'list'> for key "eval/bert_score" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# ['B: Hi Tom, are you busy tomorrow afternoon?', 'Emma wants to buy an advent calendar for her kids. Rob used to get one every year as', 'Madison is pregnant. Iggy and Jackie are worried about it. Iggy used to think that', 'Marla finds a pink underwear under her bed.', 'Robert needs to buy guitar cable. Fred will find it on google maps.', 'Keith wants to buy milk and cereals. Megan will check the drawer next to the fridge', 'Samantha and Evelyn are surprised that Samatha is making that noise.', "Tom's new place is in Fiesole. He invited Luis and Adam for dinner", 'Jane wants to make a reservation for 6 people tonight at 21:00. Vegano Resto', "Nancy's Texan drawl. Kids behaving themselves. Nancy is coming home", 'Laura needs a new printer. Jamie recommends Laura to buy a second hand one.', "Haylee is in the dairy section. She's looking for the coconut milk youg", 'Norbert and Wendy need to hurry to catch the tour. Norbert missed the last one because', 'Cheryl went to the Jandia Peninsula. Peter took nice pictures. Tomorrow they will', "Sophie hasn't found it yet.", "Dennis's favorite b-movie is Toxic Avenger. Elle", 'James wants to become a voice actor. He has a dream for a long time', 'Poppy and Alice have a long day. Alice has errands. Po', "Sash needs to see Caron. Caron is out from 12 and she's out", 'Gosia criticizes Matteo because he likes football and video games', "Jannette is coming to Ramzi's.", 'Jeniffer and Hildegard are preparing ravioli.', 'Lawrence is not finished with the article yet. He will be in a few minutes.', "Chad and Brennen are laughing at Brennen's joke.", 'Sadie needs to go to the dentist on Thursday. Chloe will pick it up', 'Carter is developing a restaurant business. He is a bit nervous about it. He is', "Kenny is back from surgery. He has another surgery tomorrow. He's got another", 'Joey and Olivia broke up after years of dating. Joey cheated on Olivia with', 'Amanda is pregnant. She went dancing classes with Michael yesterday. The instructor needed a partner to', "Taylor hasn't introduced Isabel to her boyfriend yet. Isabel hasn't introduced Taylor", 'Theo is leaving on Friday and will join him for the weekend. He will come back by', 'Brandon is late. Clara will prepare a report on absenteeism and late', "Suzie is sick again and she cancels Olga's meeting. Olga", "Kate will be Diane's kids' mother.", 'Andrew has a cold. He has to call in sick. Daniel will pick up some stuff', 'John, Alex and Sam are watching Millionaires on TV.', 'Angelica has the cinnamon cookies recipe.', 'Sophie is waiting for a client who is 40 minutes late. Sophie will let Gwen', 'Daniel is on his way. Sue is going downstairs now.', 'George will pan fry the salmon and stuff the squash with salmon. Betty will pick up some', "Ken tried to track his progress with endomondo. Martha noticed that Ken's phone", "Ivan hasn't been at Ann's party. Ann and Ivan are meeting", 'Ashley posted nudes on Facebook. Rowan thinks it\'s "art" and Row', "Mikolaj got a letter from the government saying that his wife's papers will", 'Ann is at the hotel. Thomas and Maria are going to have lunch together.', 'Sus and Val are sleepy.', "Kate and Kai are at the Guggenheim. They're going to the Museum of", "Cathy left her sunglasses at Broke's house. She will come round at 10 tonight", 'Bradley invites Frederica to his birthday party tomorrow at 8 pm.', 'Camilla received 250 dollars.', "Lilliana is waiting to have lunch and maybe nap. She's not getting paid for", 'Margaret has just had a shower. She will go shopping with Meg at 1 pm near', 'Maria Curie is the greatest Pole. Paulina thinks she is not appreciated enough in', 'Miles needs to push the project. Tim knows, Tim is doing his best. Gregory has', 'Julia is at work. Morgan wants to meet up for a drink later.', "Marta is at the supermarket to make some shopping for today's dinner. Nick hasn", 'Dzuka wants to change the time of the staff meeting. Anna will let Dzuka', "Will is checking Daniel's tests ...
# Trainer is attempting to log a value of "{'rouge1': 0.4648609117501229, 'rouge2': 0.23489748856950105, 'rougeL': 0.3936027885754436, 'rougeLsum': 0.3932448622689456}" of type <class 'dict'> for key "eval/rouge_score" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'bleu': 0.12048170853922512, 'precisions': [0.5838656689176857, 0.28994082840236685, 0.17667882428663376, 0.11335841956726246], 'brevity_penalty': 0.49929356415876747, 'length_ratio': 0.5901233238192687, 'translation_length': 10958, 'reference_length': 18569}" of type <class 'dict'> for key "eval/bleu_score" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[0.9187235832214355, 0.9003126621246338, 0.9092234373092651]" of type <class 'list'> for key "eval/bert_score" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# ['B: Hi Tom, are you busy tomorrow afternoon?', 'Emma wants to buy an advent calendar for her kids. Rob used to get one every year as', 'Madison is pregnant. Iggy and Jackie are worried about it. Iggy used to think that', 'Marla finds a pink underwear under her bed.', 'Robert needs to buy guitar cable. Fred will find it on google maps.', 'Keith wants to buy milk and cereals. Megan will check the drawer next to the fridge', 'Samantha and Evelyn are surprised that Samatha is making that noise.', "Tom's new place is in Fiesole. He invited Luis and Adam for dinner", 'Jane wants to make a reservation for 6 people tonight at 21:00. Vegano Resto', "Nancy's Texan drawl. Kids behaving themselves. Nancy is coming home", 'Laura needs a new printer. Jamie recommends Laura to buy a second hand one.', "Haylee is in the dairy section. She's looking for the coconut milk youg", 'Norbert and Wendy need to hurry to catch the tour. Norbert missed the last one because', 'Cheryl went to the Jandia Peninsula. Peter took nice pictures. Tomorrow they will', "Sophie hasn't found it yet.", "Dennis's favorite b-movie is Toxic Avenger. Elle", 'James wants to become a voice actor. He has a dream for a long time', 'Poppy and Alice have a long day. Alice has errands. Po', "Sash needs to see Caron. Caron is out from 12 and she's out", 'Gosia criticizes Matteo because he likes football and video games', "Jannette is coming to Ramzi's.", 'Jeniffer and Hildegard are preparing ravioli.', 'Lawrence is not finished with the article yet. He will be in a few minutes.', "Chad and Brennen are laughing at Brennen's joke.", 'Sadie needs to go to the dentist on Thursday. Chloe will pick it up', 'Carter is developing a restaurant business. He is a bit nervous about it. He is', "Kenny is back from surgery. He has another surgery tomorrow. He's got another", 'Joey and Olivia broke up after years of dating. Joey cheated on Olivia with', 'Amanda is pregnant. She went dancing classes with Michael yesterday. The instructor needed a partner to', "Taylor hasn't introduced Isabel to her boyfriend yet. Isabel hasn't introduced Taylor", 'Theo is leaving on Friday and will join him for the weekend. He will come back by', 'Brandon is late. Clara will prepare a report on absenteeism and late', "Suzie is sick again and she cancels Olga's meeting. Olga", "Kate will be Diane's kids' mother.", 'Andrew has a cold. He has to call in sick. Daniel will pick up some stuff', 'John, Alex and Sam are watching Millionaires on TV.', 'Angelica has the cinnamon cookies recipe.', 'Sophie is waiting for a client who is 40 minutes late. Sophie will let Gwen', 'Daniel is on his way. Sue is going downstairs now.', 'George will pan fry the salmon and stuff the squash with salmon. Betty will pick up some', "Ken tried to track his progress with endomondo. Martha noticed that Ken's phone", "Ivan hasn't been at Ann's party. Ann and Ivan are meeting", 'Ashley posted nudes on Facebook. Rowan thinks it\'s "art" and Row', "Mikolaj got a letter from the government saying that his wife's papers will", 'Ann is at the hotel. Thomas and Maria are going to have lunch together.', 'Sus and Val are sleepy.', "Kate and Kai are at the Guggenheim. They're going to the Museum of", "Cathy left her sunglasses at Broke's house. She will come round at 10 tonight", 'Bradley invites Frederica to his birthday party tomorrow at 8 pm.', 'Camilla received 250 dollars.', "Lilliana is waiting to have lunch and maybe nap. She's not getting paid for", 'Margaret has just had a shower. She will go shopping with Meg at 1 pm near', 'Maria Curie is the greatest Pole. Paulina thinks she is not appreciated enough in', 'Miles needs to push the project. Tim knows, Tim is doing his best. Gregory has', 'Julia is at work. Morgan wants to meet up for a drink later.', "Marta is at the supermarket to make some shopping for today's dinner. Nick hasn", 'Dzuka wants to change the time of the staff meeting. Anna will let Dzuka', "Will is checking Daniel's tests ...
# Trainer is attempting to log a value of "{'rouge1': 0.4648609117501229, 'rouge2': 0.23489748856950105, 'rougeL': 0.3936027885754436, 'rougeLsum': 0.3932448622689456}" of type <class 'dict'> for key "eval/rouge_score" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'bleu': 0.12048170853922512, 'precisions': [0.5838656689176857, 0.28994082840236685, 0.17667882428663376, 0.11335841956726246], 'brevity_penalty': 0.49929356415876747, 'length_ratio': 0.5901233238192687, 'translation_length': 10958, 'reference_length': 18569}" of type <class 'dict'> for key "eval/bleu_score" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[0.9187235832214355, 0.9003126621246338, 0.9092234373092651]" of type <class 'list'> for key "eval/bert_score" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# ['B: Hi Tom, are you busy tomorrow afternoon?', 'Emma wants to buy an advent calendar for her kids. Rob used to get one every year as', 'Madison is pregnant. Iggy and Jackie are worried about it. Iggy used to think that', 'Marla finds a pink underwear under her bed.', 'Robert needs to buy guitar cable. Fred will find it on google maps.', 'Keith wants to buy milk and cereals. Megan will check the drawer next to the fridge', 'Samantha and Evelyn are surprised that Samatha is making that noise.', "Tom's new place is in Fiesole. He invited Luis and Adam for dinner", 'Jane wants to make a reservation for 6 people tonight at 21:00. Vegano Resto', "Nancy's Texan drawl. Kids behaving themselves. Nancy is coming home", 'Laura needs a new printer. Jamie recommends Laura to buy a second hand one.', "Haylee is in the dairy section. She's looking for the coconut milk youg", 'Norbert and Wendy need to hurry to catch the tour. Norbert missed the last one because', 'Cheryl went to the Jandia Peninsula. Peter took nice pictures. Tomorrow they will', "Sophie hasn't found it yet.", "Dennis's favorite b-movie is Toxic Avenger. Elle", 'James wants to become a voice actor. He has a dream for a long time', 'Poppy and Alice have a long day. Alice has errands. Po', "Sash needs to see Caron. Caron is out from 12 and she's out", 'Gosia criticizes Matteo because he likes football and video games', "Jannette is coming to Ramzi's.", 'Jeniffer and Hildegard are preparing ravioli.', 'Lawrence is not finished with the article yet. He will be in a few minutes.', "Chad and Brennen are laughing at Brennen's joke.", 'Sadie needs to go to the dentist on Thursday. Chloe will pick it up', 'Carter is developing a restaurant business. He is a bit nervous about it. He is', "Kenny is back from surgery. He has another surgery tomorrow. He's got another", 'Joey and Olivia broke up after years of dating. Joey cheated on Olivia with', 'Amanda is pregnant. She went dancing classes with Michael yesterday. The instructor needed a partner to', "Taylor hasn't introduced Isabel to her boyfriend yet. Isabel hasn't introduced Taylor", 'Theo is leaving on Friday and will join him for the weekend. He will come back by', 'Brandon is late. Clara will prepare a report on absenteeism and late', "Suzie is sick again and she cancels Olga's meeting. Olga", "Kate will be Diane's kids' mother.", 'Andrew has a cold. He has to call in sick. Daniel will pick up some stuff', 'John, Alex and Sam are watching Millionaires on TV.', 'Angelica has the cinnamon cookies recipe.', 'Sophie is waiting for a client who is 40 minutes late. Sophie will let Gwen', 'Daniel is on his way. Sue is going downstairs now.', 'George will pan fry the salmon and stuff the squash with salmon. Betty will pick up some', "Ken tried to track his progress with endomondo. Martha noticed that Ken's phone", "Ivan hasn't been at Ann's party. Ann and Ivan are meeting", 'Ashley posted nudes on Facebook. Rowan thinks it\'s "art" and Row', "Mikolaj got a letter from the government saying that his wife's papers will", 'Ann is at the hotel. Thomas and Maria are going to have lunch together.', 'Sus and Val are sleepy.', "Kate and Kai are at the Guggenheim. They're going to the Museum of", "Cathy left her sunglasses at Broke's house. She will come round at 10 tonight", 'Bradley invites Frederica to his birthday party tomorrow at 8 pm.', 'Camilla received 250 dollars.', "Lilliana is waiting to have lunch and maybe nap. She's not getting paid for", 'Margaret has just had a shower. She will go shopping with Meg at 1 pm near', 'Maria Curie is the greatest Pole. Paulina thinks she is not appreciated enough in', 'Miles needs to push the project. Tim knows, Tim is doing his best. Gregory has', 'Julia is at work. Morgan wants to meet up for a drink later.', "Marta is at the supermarket to make some shopping for today's dinner. Nick hasn", 'Dzuka wants to change the time of the staff meeting. Anna will let Dzuka', "Will is checking Daniel's tests ...
# Trainer is attempting to log a value of "{'rouge1': 0.4648609117501229, 'rouge2': 0.23489748856950105, 'rougeL': 0.3936027885754436, 'rougeLsum': 0.3932448622689456}" of type <class 'dict'> for key "eval/rouge_score" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'bleu': 0.12048170853922512, 'precisions': [0.5838656689176857, 0.28994082840236685, 0.17667882428663376, 0.11335841956726246], 'brevity_penalty': 0.49929356415876747, 'length_ratio': 0.5901233238192687, 'translation_length': 10958, 'reference_length': 18569}" of type <class 'dict'> for key "eval/bleu_score" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[0.9187235832214355, 0.9003126621246338, 0.9092234373092651]" of type <class 'list'> for key "eval/bert_score" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# ['B: Hi Tom, are you busy tomorrow afternoon?', 'Emma wants to buy an advent calendar for her kids. Rob used to get one every year as', 'Madison is pregnant. Iggy and Jackie are worried about it. Iggy used to think that', 'Marla finds a pink underwear under her bed.', 'Robert needs to buy guitar cable. Fred will find it on google maps.', 'Keith wants to buy milk and cereals. Megan will check the drawer next to the fridge', 'Samantha and Evelyn are surprised that Samatha is making that noise.', "Tom's new place is in Fiesole. He invited Luis and Adam for dinner", 'Jane wants to make a reservation for 6 people tonight at 21:00. Vegano Resto', "Nancy's Texan drawl. Kids behaving themselves. Nancy is coming home", 'Laura needs a new printer. Jamie recommends Laura to buy a second hand one.', "Haylee is in the dairy section. She's looking for the coconut milk youg", 'Norbert and Wendy need to hurry to catch the tour. Norbert missed the last one because', 'Cheryl went to the Jandia Peninsula. Peter took nice pictures. Tomorrow they will', "Sophie hasn't found it yet.", "Dennis's favorite b-movie is Toxic Avenger. Elle", 'James wants to become a voice actor. He has a dream for a long time', 'Poppy and Alice have a long day. Alice has errands. Po', "Sash needs to see Caron. Caron is out from 12 and she's out", 'Gosia criticizes Matteo because he likes football and video games', "Jannette is coming to Ramzi's.", 'Jeniffer and Hildegard are preparing ravioli.', 'Lawrence is not finished with the article yet. He will be in a few minutes.', "Chad and Brennen are laughing at Brennen's joke.", 'Sadie needs to go to the dentist on Thursday. Chloe will pick it up', 'Carter is developing a restaurant business. He is a bit nervous about it. He is', "Kenny is back from surgery. He has another surgery tomorrow. He's got another", 'Joey and Olivia broke up after years of dating. Joey cheated on Olivia with', 'Amanda is pregnant. She went dancing classes with Michael yesterday. The instructor needed a partner to', "Taylor hasn't introduced Isabel to her boyfriend yet. Isabel hasn't introduced Taylor", 'Theo is leaving on Friday and will join him for the weekend. He will come back by', 'Brandon is late. Clara will prepare a report on absenteeism and late', "Suzie is sick again and she cancels Olga's meeting. Olga", "Kate will be Diane's kids' mother.", 'Andrew has a cold. He has to call in sick. Daniel will pick up some stuff', 'John, Alex and Sam are watching Millionaires on TV.', 'Angelica has the cinnamon cookies recipe.', 'Sophie is waiting for a client who is 40 minutes late. Sophie will let Gwen', 'Daniel is on his way. Sue is going downstairs now.', 'George will pan fry the salmon and stuff the squash with salmon. Betty will pick up some', "Ken tried to track his progress with endomondo. Martha noticed that Ken's phone", "Ivan hasn't been at Ann's party. Ann and Ivan are meeting", 'Ashley posted nudes on Facebook. Rowan thinks it\'s "art" and Row', "Mikolaj got a letter from the government saying that his wife's papers will", 'Ann is at the hotel. Thomas and Maria are going to have lunch together.', 'Sus and Val are sleepy.', "Kate and Kai are at the Guggenheim. They're going to the Museum of", "Cathy left her sunglasses at Broke's house. She will come round at 10 tonight", 'Bradley invites Frederica to his birthday party tomorrow at 8 pm.', 'Camilla received 250 dollars.', "Lilliana is waiting to have lunch and maybe nap. She's not getting paid for", 'Margaret has just had a shower. She will go shopping with Meg at 1 pm near', 'Maria Curie is the greatest Pole. Paulina thinks she is not appreciated enough in', 'Miles needs to push the project. Tim knows, Tim is doing his best. Gregory has', 'Julia is at work. Morgan wants to meet up for a drink later.', "Marta is at the supermarket to make some shopping for today's dinner. Nick hasn", 'Dzuka wants to change the time of the staff meeting. Anna will let Dzuka', "Will is checking Daniel's tests ...
# Trainer is attempting to log a value of "{'rouge1': 0.4648609117501229, 'rouge2': 0.23489748856950105, 'rougeL': 0.3936027885754436, 'rougeLsum': 0.3932448622689456}" of type <class 'dict'> for key "eval/rouge_score" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'bleu': 0.12048170853922512, 'precisions': [0.5838656689176857, 0.28994082840236685, 0.17667882428663376, 0.11335841956726246], 'brevity_penalty': 0.49929356415876747, 'length_ratio': 0.5901233238192687, 'translation_length': 10958, 'reference_length': 18569}" of type <class 'dict'> for key "eval/bleu_score" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[0.9187235832214355, 0.9003126621246338, 0.9092234373092651]" of type <class 'list'> for key "eval/bert_score" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# ['B: Hi Tom, are you busy tomorrow afternoon?', 'Emma wants to buy an advent calendar for her kids. Rob used to get one every year as', 'Madison is pregnant. Iggy and Jackie are worried about it. Iggy used to think that', 'Marla finds a pink underwear under her bed.', 'Robert needs to buy guitar cable. Fred will find it on google maps.', 'Keith wants to buy milk and cereals. Megan will check the drawer next to the fridge', 'Samantha and Evelyn are surprised that Samatha is making that noise.', "Tom's new place is in Fiesole. He invited Luis and Adam for dinner", 'Jane wants to make a reservation for 6 people tonight at 21:00. Vegano Resto', "Nancy's Texan drawl. Kids behaving themselves. Nancy is coming home", 'Laura needs a new printer. Jamie recommends Laura to buy a second hand one.', "Haylee is in the dairy section. She's looking for the coconut milk youg", 'Norbert and Wendy need to hurry to catch the tour. Norbert missed the last one because', 'Cheryl went to the Jandia Peninsula. Peter took nice pictures. Tomorrow they will', "Sophie hasn't found it yet.", "Dennis's favorite b-movie is Toxic Avenger. Elle", 'James wants to become a voice actor. He has a dream for a long time', 'Poppy and Alice have a long day. Alice has errands. Po', "Sash needs to see Caron. Caron is out from 12 and she's out", 'Gosia criticizes Matteo because he likes football and video games', "Jannette is coming to Ramzi's.", 'Jeniffer and Hildegard are preparing ravioli.', 'Lawrence is not finished with the article yet. He will be in a few minutes.', "Chad and Brennen are laughing at Brennen's joke.", 'Sadie needs to go to the dentist on Thursday. Chloe will pick it up', 'Carter is developing a restaurant business. He is a bit nervous about it. He is', "Kenny is back from surgery. He has another surgery tomorrow. He's got another", 'Joey and Olivia broke up after years of dating. Joey cheated on Olivia with', 'Amanda is pregnant. She went dancing classes with Michael yesterday. The instructor needed a partner to', "Taylor hasn't introduced Isabel to her boyfriend yet. Isabel hasn't introduced Taylor", 'Theo is leaving on Friday and will join him for the weekend. He will come back by', 'Brandon is late. Clara will prepare a report on absenteeism and late', "Suzie is sick again and she cancels Olga's meeting. Olga", "Kate will be Diane's kids' mother.", 'Andrew has a cold. He has to call in sick. Daniel will pick up some stuff', 'John, Alex and Sam are watching Millionaires on TV.', 'Angelica has the cinnamon cookies recipe.', 'Sophie is waiting for a client who is 40 minutes late. Sophie will let Gwen', 'Daniel is on his way. Sue is going downstairs now.', 'George will pan fry the salmon and stuff the squash with salmon. Betty will pick up some', "Ken tried to track his progress with endomondo. Martha noticed that Ken's phone", "Ivan hasn't been at Ann's party. Ann and Ivan are meeting", 'Ashley posted nudes on Facebook. Rowan thinks it\'s "art" and Row', "Mikolaj got a letter from the government saying that his wife's papers will", 'Ann is at the hotel. Thomas and Maria are going to have lunch together.', 'Sus and Val are sleepy.', "Kate and Kai are at the Guggenheim. They're going to the Museum of", "Cathy left her sunglasses at Broke's house. She will come round at 10 tonight", 'Bradley invites Frederica to his birthday party tomorrow at 8 pm.', 'Camilla received 250 dollars.', "Lilliana is waiting to have lunch and maybe nap. She's not getting paid for", 'Margaret has just had a shower. She will go shopping with Meg at 1 pm near', 'Maria Curie is the greatest Pole. Paulina thinks she is not appreciated enough in', 'Miles needs to push the project. Tim knows, Tim is doing his best. Gregory has', 'Julia is at work. Morgan wants to meet up for a drink later.', "Marta is at the supermarket to make some shopping for today's dinner. Nick hasn", 'Dzuka wants to change the time of the staff meeting. Anna will let Dzuka', "Will is checking Daniel's tests ...
# Trainer is attempting to log a value of "{'rouge1': 0.4648609117501229, 'rouge2': 0.23489748856950105, 'rougeL': 0.3936027885754436, 'rougeLsum': 0.3932448622689456}" of type <class 'dict'> for key "eval/rouge_score" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'bleu': 0.12048170853922512, 'precisions': [0.5838656689176857, 0.28994082840236685, 0.17667882428663376, 0.11335841956726246], 'brevity_penalty': 0.49929356415876747, 'length_ratio': 0.5901233238192687, 'translation_length': 10958, 'reference_length': 18569}" of type <class 'dict'> for key "eval/bleu_score" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[0.9187235832214355, 0.9003126621246338, 0.9092234373092651]" of type <class 'list'> for key "eval/bert_score" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# ['B: Hi Tom, are you busy tomorrow afternoon?', 'Emma wants to buy an advent calendar for her kids. Rob used to get one every year as', 'Madison is pregnant. Iggy and Jackie are worried about it. Iggy used to think that', 'Marla finds a pink underwear under her bed.', 'Robert needs to buy guitar cable. Fred will find it on google maps.', 'Keith wants to buy milk and cereals. Megan will check the drawer next to the fridge', 'Samantha and Evelyn are surprised that Samatha is making that noise.', "Tom's new place is in Fiesole. He invited Luis and Adam for dinner", 'Jane wants to make a reservation for 6 people tonight at 21:00. Vegano Resto', "Nancy's Texan drawl. Kids behaving themselves. Nancy is coming home", 'Laura needs a new printer. Jamie recommends Laura to buy a second hand one.', "Haylee is in the dairy section. She's looking for the coconut milk youg", 'Norbert and Wendy need to hurry to catch the tour. Norbert missed the last one because', 'Cheryl went to the Jandia Peninsula. Peter took nice pictures. Tomorrow they will', "Sophie hasn't found it yet.", "Dennis's favorite b-movie is Toxic Avenger. Elle", 'James wants to become a voice actor. He has a dream for a long time', 'Poppy and Alice have a long day. Alice has errands. Po', "Sash needs to see Caron. Caron is out from 12 and she's out", 'Gosia criticizes Matteo because he likes football and video games', "Jannette is coming to Ramzi's.", 'Jeniffer and Hildegard are preparing ravioli.', 'Lawrence is not finished with the article yet. He will be in a few minutes.', "Chad and Brennen are laughing at Brennen's joke.", 'Sadie needs to go to the dentist on Thursday. Chloe will pick it up', 'Carter is developing a restaurant business. He is a bit nervous about it. He is', "Kenny is back from surgery. He has another surgery tomorrow. He's got another", 'Joey and Olivia broke up after years of dating. Joey cheated on Olivia with', 'Amanda is pregnant. She went dancing classes with Michael yesterday. The instructor needed a partner to', "Taylor hasn't introduced Isabel to her boyfriend yet. Isabel hasn't introduced Taylor", 'Theo is leaving on Friday and will join him for the weekend. He will come back by', 'Brandon is late. Clara will prepare a report on absenteeism and late', "Suzie is sick again and she cancels Olga's meeting. Olga", "Kate will be Diane's kids' mother.", 'Andrew has a cold. He has to call in sick. Daniel will pick up some stuff', 'John, Alex and Sam are watching Millionaires on TV.', 'Angelica has the cinnamon cookies recipe.', 'Sophie is waiting for a client who is 40 minutes late. Sophie will let Gwen', 'Daniel is on his way. Sue is going downstairs now.', 'George will pan fry the salmon and stuff the squash with salmon. Betty will pick up some', "Ken tried to track his progress with endomondo. Martha noticed that Ken's phone", "Ivan hasn't been at Ann's party. Ann and Ivan are meeting", 'Ashley posted nudes on Facebook. Rowan thinks it\'s "art" and Row', "Mikolaj got a letter from the government saying that his wife's papers will", 'Ann is at the hotel. Thomas and Maria are going to have lunch together.', 'Sus and Val are sleepy.', "Kate and Kai are at the Guggenheim. They're going to the Museum of", "Cathy left her sunglasses at Broke's house. She will come round at 10 tonight", 'Bradley invites Frederica to his birthday party tomorrow at 8 pm.', 'Camilla received 250 dollars.', "Lilliana is waiting to have lunch and maybe nap. She's not getting paid for", 'Margaret has just had a shower. She will go shopping with Meg at 1 pm near', 'Maria Curie is the greatest Pole. Paulina thinks she is not appreciated enough in', 'Miles needs to push the project. Tim knows, Tim is doing his best. Gregory has', 'Julia is at work. Morgan wants to meet up for a drink later.', "Marta is at the supermarket to make some shopping for today's dinner. Nick hasn", 'Dzuka wants to change the time of the staff meeting. Anna will let Dzuka', "Will is checking Daniel's tests ...
# Trainer is attempting to log a value of "{'rouge1': 0.4648609117501229, 'rouge2': 0.23489748856950105, 'rougeL': 0.3936027885754436, 'rougeLsum': 0.3932448622689456}" of type <class 'dict'> for key "eval/rouge_score" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'bleu': 0.12048170853922512, 'precisions': [0.5838656689176857, 0.28994082840236685, 0.17667882428663376, 0.11335841956726246], 'brevity_penalty': 0.49929356415876747, 'length_ratio': 0.5901233238192687, 'translation_length': 10958, 'reference_length': 18569}" of type <class 'dict'> for key "eval/bleu_score" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[0.9187235832214355, 0.9003126621246338, 0.9092234373092651]" of type <class 'list'> for key "eval/bert_score" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# TrainOutput(global_step=9210, training_loss=0.0, metrics={'train_runtime': 5442.2292, 'train_samples_per_second': 27.07, 'train_steps_per_second': 1.692, 'total_flos': 5.043922658131968e+16, 'train_loss': 0.0, 'epoch': 10.0})

# %%
trainer.push_to_hub()
# Out:
# Upload file pytorch_model.bin:   0%|          | 1.00/945M [00:00<?, ?B/s]
# Upload file runs/Jul30_07-35-23_a09bf80fcd43/events.out.tfevents.1690702529.a09bf80fcd43.11997.0:   0%|       …
# Upload file runs/Jul30_07-30-06_a09bf80fcd43/events.out.tfevents.1690702211.a09bf80fcd43.3925.1:   0%|        …
# Upload file runs/Jul30_07-05-49_a09bf80fcd43/events.out.tfevents.1690700755.a09bf80fcd43.3925.0:   0%|        …
# Upload file runs/Jul30_06-55-35_a09bf80fcd43/events.out.tfevents.1690700144.a09bf80fcd43.555.0:   0%|         …
# Upload file runs/Jul30_07-31-51_a09bf80fcd43/events.out.tfevents.1690702314.a09bf80fcd43.3925.2:   0%|        …
# Upload file spiece.model:   0%|          | 1.00/773k [00:00<?, ?B/s]
# Upload file training_args.bin:   0%|          | 1.00/4.06k [00:00<?, ?B/s]
# To https://huggingface.co/sentientconch/flant5_sum_samsum
#    5e5d077..e8a3184  main -> main
#
# WARNING:huggingface_hub.repository:To https://huggingface.co/sentientconch/flant5_sum_samsum
#    5e5d077..e8a3184  main -> main
#
# To https://huggingface.co/sentientconch/flant5_sum_samsum
#    e8a3184..35821b1  main -> main
#
# WARNING:huggingface_hub.repository:To https://huggingface.co/sentientconch/flant5_sum_samsum
#    e8a3184..35821b1  main -> main
# 'https://huggingface.co/sentientconch/flant5_sum_samsum/commit/e8a31840dde8e25284d86a6aa8d115ebe692d7d7'

# %% [markdown]
# Example inference

# %%
from transformers import pipeline

summarizer = pipeline("summarization", model=model.to('cpu'), tokenizer=tokenizer)
summarizer("summarize: "+dataset['test'][1]['dialogue'])
# Out:
# Your max_length is set to 200, but your input_length is only 157. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=78)
# [{'summary_text': "Eric and Rob like Eric's stand-ups on youtube. Eric is going to watch them now. Rob will watch them. Eric likes the train part."}]

# %%
dataset['test'][1]
# Out:
# {'id': '13729565',
#  'summary': 'Eric and Rob are going to watch a stand-up on youtube.',
#  'dialogue': "Eric: MACHINE! Rob: That's so gr8! Eric: I know! And shows how Americans see Russian ;) Rob: And it's really funny! Eric: I know! I especially like the train part! Rob: Hahaha! No one talks to the machine like that! Eric: Is this his only stand-up? Rob: Idk. I'll check. Eric: Sure. Rob: Turns out no! There are some of his stand-ups on youtube. Eric: Gr8! I'll watch them now! Rob: Me too! Eric: MACHINE! Rob: MACHINE! Eric: TTYL? Rob: Sure :)"}
